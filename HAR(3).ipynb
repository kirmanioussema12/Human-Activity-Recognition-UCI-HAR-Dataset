# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, Dropout, Add, LSTM, Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report
import tensorflow as tf

# --- Load all sensor data and stack into 3D array (samples, timesteps, features) ---

def load_sensor_data(base_path, sensor_name):
    # sensor_name e.g. 'body_acc_x_train.txt'
    df = pd.read_csv(base_path + sensor_name, delim_whitespace=True, header=None)
    return df.values

base_path = r"C:\Users\MSI\Desktop\Mitacs Project\Human Activity Recognition\UCI HAR Dataset\train\Inertial Signals\\"

# Load all 9 sensor axes
body_acc_x = load_sensor_data(base_path, 'body_acc_x_train.txt')
body_acc_y = load_sensor_data(base_path, 'body_acc_y_train.txt')
body_acc_z = load_sensor_data(base_path, 'body_acc_z_train.txt')

body_gyro_x = load_sensor_data(base_path, 'body_gyro_x_train.txt')
body_gyro_y = load_sensor_data(base_path, 'body_gyro_y_train.txt')
body_gyro_z = load_sensor_data(base_path, 'body_gyro_z_train.txt')

total_acc_x = load_sensor_data(base_path, 'total_acc_x_train.txt')
total_acc_y = load_sensor_data(base_path, 'total_acc_y_train.txt')
total_acc_z = load_sensor_data(base_path, 'total_acc_z_train.txt')

# Stack all 9 axes into (samples, timesteps, features=9)
# Each input file shape: (7352, 128) -- 7352 samples, 128 time steps each
X = np.stack([
    body_acc_x, body_acc_y, body_acc_z,
    body_gyro_x, body_gyro_y, body_gyro_z,
    total_acc_x, total_acc_y, total_acc_z
], axis=2)  # shape: (7352, 128, 9)

print("X shape:", X.shape)

# Load labels
y = pd.read_csv(r"C:\Users\MSI\Desktop\Mitacs Project\Human Activity Recognition\UCI HAR Dataset\train\y_train.txt", delim_whitespace=True, header=None).values.flatten()

# --- Standardize data per feature (flatten first) ---
nsamples, ntimesteps, nfeatures = X.shape
X_reshaped = X.reshape(-1, nfeatures)  # shape (7352*128, 9)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_reshaped)

X_scaled = X_scaled.reshape(nsamples, ntimesteps, nfeatures)

# Encode labels to 0-based integers
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

print("Labels:", np.unique(y_encoded))
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_24564\669504868.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(base_path + sensor_name, delim_whitespace=True, header=None)
# C:\Users\MSI\AppData\Local\Temp\ipykernel_24564\669504868.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(base_path + sensor_name, delim_whitespace=True, header=None)
# C:\Users\MSI\AppData\Local\Temp\ipykernel_24564\669504868.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(base_path + sensor_name, delim_whitespace=True, header=None)
# C:\Users\MSI\AppData\Local\Temp\ipykernel_24564\669504868.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(base_path + sensor_name, delim_whitespace=True, header=None)
# C:\Users\MSI\AppData\Local\Temp\ipykernel_24564\669504868.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(base_path + sensor_name, delim_whitespace=True, header=None)
# C:\Users\MSI\AppData\Local\Temp\ipykernel_24564\669504868.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(base_path + sensor_name, delim_whitespace=True, header=None)
# C:\Users\MSI\AppData\Local\Temp\ipykernel_24564\669504868.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(base_path + sensor_name, delim_whitespace=True, header=None)
# C:\Users\MSI\AppData\Local\Temp\ipykernel_24564\669504868.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(base_path + sensor_name, delim_whitespace=True, header=None)
# C:\Users\MSI\AppData\Local\Temp\ipykernel_24564\669504868.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(base_path + sensor_name, delim_whitespace=True, header=None)
# X shape: (7352, 128, 9)
# C:\Users\MSI\AppData\Local\Temp\ipykernel_24564\669504868.py:45: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   y = pd.read_csv(r"C:\Users\MSI\Desktop\Mitacs Project\Human Activity Recognition\UCI HAR Dataset\train\y_train.txt", delim_whitespace=True, header=None).values.flatten()
# Labels: [0 1 2 3 4 5]

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, Dropout, GRU, Dense, Add, MaxPooling1D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import numpy as np

# --- Model Building Function ---
def build_cnn_gru_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Conv1D(64, kernel_size=5, padding='same', activation='relu', kernel_regularizer=l2(0.01))(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = MaxPooling1D(pool_size=2)(x)  # Added MaxPooling1D layer

    conv1 = Conv1D(64, kernel_size=5, padding='same', activation='relu', kernel_regularizer=l2(0.01))(x)
    conv1 = BatchNormalization()(conv1)
    x = Add()([x, conv1])
    x = Dropout(0.2)(x)

    x = Conv1D(128, kernel_size=5, padding='same', activation='relu', kernel_regularizer=l2(0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    x = GRU(128, return_sequences=False, kernel_regularizer=l2(0.01))(x)  # GRU replaces LSTM
    x = Dropout(0.2)(x)
    x = Dense(128, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = Dropout(0.2)(x)

    outputs = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# --- Plotting Training History ---
def plot_training_history(histories):
    for i, history in enumerate(histories, 1):
        plt.figure(figsize=(12, 4))

        # Loss plot
        plt.subplot(1, 2, 1)
        plt.plot(history.history['loss'], label='Train Loss')
        plt.plot(history.history['val_loss'], label='Val Loss')
        plt.title(f'Fold {i} - Loss Curve')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()

        # Accuracy plot
        plt.subplot(1, 2, 2)
        plt.plot(history.history['accuracy'], label='Train Accuracy')
        plt.plot(history.history['val_accuracy'], label='Val Accuracy')
        plt.title(f'Fold {i} - Accuracy Curve')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()

        plt.tight_layout()
        plt.show()

# --- Stratified K-Fold Training ---
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
fold = 1
f1_scores = []
histories = []

# Compute class weights
class_weights = compute_class_weight('balanced', classes=np.unique(y_encoded), y=y_encoded)
class_weight_dict = dict(enumerate(class_weights))

for train_idx, val_idx in skf.split(X_scaled, y_encoded):
    print(f"\n📚 Training Fold {fold}")
    X_train, X_val = X_scaled[train_idx], X_scaled[val_idx]
    y_train, y_val = y_encoded[train_idx], y_encoded[val_idx]

    model = build_cnn_gru_model(input_shape=(ntimesteps, nfeatures), num_classes=len(np.unique(y_encoded)))

    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

    history = model.fit(
        X_train, y_train,
        epochs=50,
        batch_size=64,
        class_weight=class_weight_dict,
        validation_data=(X_val, y_val),
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )

    histories.append(history)

    y_pred = model.predict(X_val)
    y_pred_classes = np.argmax(y_pred, axis=1)

    print(f"\n🧾 Fold {fold} Classification Report:")
    print(classification_report(y_val, y_pred_classes, target_names=label_encoder.classes_.astype(str)))

    report = classification_report(y_val, y_pred_classes, output_dict=True)
    f1_scores.append(report['macro avg']['f1-score'])

    fold += 1

# Final results
print(f"\n✅ Average Macro F1-Score across {skf.n_splits} folds: {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")

# Plot training history
plot_training_history(histories)
# Out:
# 📚 Training Fold 1
# Epoch 1/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 11s 84ms/step - accuracy: 0.6553 - loss: 4.7745 - val_accuracy: 0.8967 - val_loss: 2.1657 - learning_rate: 0.0010
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.9371 - loss: 1.6685 - val_accuracy: 0.8838 - val_loss: 1.1456 - learning_rate: 0.0010
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - accuracy: 0.9278 - loss: 0.8773 - val_accuracy: 0.8593 - val_loss: 0.9468 - learning_rate: 0.0010
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.9330 - loss: 0.5800 - val_accuracy: 0.8804 - val_loss: 0.6149 - learning_rate: 0.0010
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9408 - loss: 0.4467 - val_accuracy: 0.9490 - val_loss: 0.3747 - learning_rate: 0.0010
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9482 - loss: 0.3698 - val_accuracy: 0.9517 - val_loss: 0.3181 - learning_rate: 0.0010
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9347 - loss: 0.3513 - val_accuracy: 0.9375 - val_loss: 0.3906 - learning_rate: 0.0010
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9336 - loss: 0.3751 - val_accuracy: 0.9062 - val_loss: 0.4051 - learning_rate: 0.0010
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9486 - loss: 0.2743 - val_accuracy: 0.9334 - val_loss: 0.3397 - learning_rate: 0.0010
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9479 - loss: 0.2893 - val_accuracy: 0.9524 - val_loss: 0.2571 - learning_rate: 5.0000e-04
# Epoch 11/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9546 - loss: 0.2369 - val_accuracy: 0.9558 - val_loss: 0.2243 - learning_rate: 5.0000e-04
# Epoch 12/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.9474 - loss: 0.2225 - val_accuracy: 0.9293 - val_loss: 0.2543 - learning_rate: 5.0000e-04
# Epoch 13/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.9435 - loss: 0.2277 - val_accuracy: 0.9205 - val_loss: 0.3699 - learning_rate: 5.0000e-04
# Epoch 14/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.9450 - loss: 0.2523 - val_accuracy: 0.9545 - val_loss: 0.2391 - learning_rate: 5.0000e-04
# Epoch 15/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.9503 - loss: 0.2167 - val_accuracy: 0.9497 - val_loss: 0.2050 - learning_rate: 2.5000e-04
# Epoch 16/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9542 - loss: 0.1987 - val_accuracy: 0.9524 - val_loss: 0.1958 - learning_rate: 2.5000e-04
# Epoch 17/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9554 - loss: 0.1888 - val_accuracy: 0.9558 - val_loss: 0.1848 - learning_rate: 2.5000e-04
# Epoch 18/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9550 - loss: 0.1829 - val_accuracy: 0.9531 - val_loss: 0.1751 - learning_rate: 2.5000e-04
# Epoch 19/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9554 - loss: 0.1702 - val_accuracy: 0.9347 - val_loss: 0.2218 - learning_rate: 2.5000e-04
# Epoch 20/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9479 - loss: 0.1922 - val_accuracy: 0.9511 - val_loss: 0.1801 - learning_rate: 2.5000e-04
# Epoch 21/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9482 - loss: 0.1813 - val_accuracy: 0.9531 - val_loss: 0.1785 - learning_rate: 2.5000e-04
# Epoch 22/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9541 - loss: 0.1706 - val_accuracy: 0.9579 - val_loss: 0.1713 - learning_rate: 1.2500e-04
# Epoch 23/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9534 - loss: 0.1684 - val_accuracy: 0.9511 - val_loss: 0.1673 - learning_rate: 1.2500e-04
# Epoch 24/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9594 - loss: 0.1549 - val_accuracy: 0.9572 - val_loss: 0.1679 - learning_rate: 1.2500e-04
# Epoch 25/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9574 - loss: 0.1633 - val_accuracy: 0.9524 - val_loss: 0.1743 - learning_rate: 1.2500e-04
# Epoch 26/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9497 - loss: 0.1675 - val_accuracy: 0.9524 - val_loss: 0.1571 - learning_rate: 1.2500e-04
# Epoch 27/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9563 - loss: 0.1494 - val_accuracy: 0.9470 - val_loss: 0.1748 - learning_rate: 1.2500e-04
# Epoch 28/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9616 - loss: 0.1475 - val_accuracy: 0.9497 - val_loss: 0.1591 - learning_rate: 1.2500e-04
# Epoch 29/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9563 - loss: 0.1502 - val_accuracy: 0.9477 - val_loss: 0.1654 - learning_rate: 1.2500e-04
# Epoch 30/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9589 - loss: 0.1445 - val_accuracy: 0.9511 - val_loss: 0.1476 - learning_rate: 6.2500e-05
# Epoch 31/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9558 - loss: 0.1471 - val_accuracy: 0.9490 - val_loss: 0.1525 - learning_rate: 6.2500e-05
# Epoch 32/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9596 - loss: 0.1422 - val_accuracy: 0.9517 - val_loss: 0.1477 - learning_rate: 6.2500e-05
# Epoch 33/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.9599 - loss: 0.1387 - val_accuracy: 0.9545 - val_loss: 0.1499 - learning_rate: 6.2500e-05
# Epoch 34/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.9597 - loss: 0.1417 - val_accuracy: 0.9517 - val_loss: 0.1429 - learning_rate: 3.1250e-05
# Epoch 35/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.9628 - loss: 0.1309 - val_accuracy: 0.9524 - val_loss: 0.1398 - learning_rate: 3.1250e-05
# Epoch 36/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9571 - loss: 0.1389 - val_accuracy: 0.9511 - val_loss: 0.1445 - learning_rate: 3.1250e-05
# Epoch 37/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.9636 - loss: 0.1346 - val_accuracy: 0.9531 - val_loss: 0.1374 - learning_rate: 3.1250e-05
# Epoch 38/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9597 - loss: 0.1322 - val_accuracy: 0.9524 - val_loss: 0.1454 - learning_rate: 3.1250e-05
# Epoch 39/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9626 - loss: 0.1269 - val_accuracy: 0.9511 - val_loss: 0.1459 - learning_rate: 3.1250e-05
# Epoch 40/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.9652 - loss: 0.1229 - val_accuracy: 0.9504 - val_loss: 0.1492 - learning_rate: 3.1250e-05
# Epoch 41/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9673 - loss: 0.1201 - val_accuracy: 0.9531 - val_loss: 0.1378 - learning_rate: 1.5625e-05
# Epoch 42/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.9645 - loss: 0.1234 - val_accuracy: 0.9524 - val_loss: 0.1327 - learning_rate: 1.5625e-05
# Epoch 43/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.9619 - loss: 0.1264 - val_accuracy: 0.9524 - val_loss: 0.1375 - learning_rate: 1.5625e-05
# Epoch 44/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.9655 - loss: 0.1223 - val_accuracy: 0.9531 - val_loss: 0.1307 - learning_rate: 1.5625e-05
# Epoch 45/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.9690 - loss: 0.1114 - val_accuracy: 0.9511 - val_loss: 0.1315 - learning_rate: 1.5625e-05
# Epoch 46/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.9667 - loss: 0.1235 - val_accuracy: 0.9538 - val_loss: 0.1271 - learning_rate: 1.5625e-05
# Epoch 47/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.9629 - loss: 0.1261 - val_accuracy: 0.9524 - val_loss: 0.1294 - learning_rate: 1.5625e-05
# Epoch 48/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.9648 - loss: 0.1231 - val_accuracy: 0.9511 - val_loss: 0.1311 - learning_rate: 1.5625e-05
# Epoch 49/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.9646 - loss: 0.1189 - val_accuracy: 0.9599 - val_loss: 0.1249 - learning_rate: 1.5625e-05
# Epoch 50/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9645 - loss: 0.1223 - val_accuracy: 0.9551 - val_loss: 0.1272 - learning_rate: 1.5625e-05
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
#
# 🧾 Fold 1 Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       245
#            2       1.00      1.00      1.00       215
#            3       1.00      1.00      1.00       197
#            4       0.85      0.94      0.89       257
#            5       0.94      0.84      0.89       275
#            6       1.00      1.00      1.00       282
#
#     accuracy                           0.96      1471
#    macro avg       0.96      0.96      0.96      1471
# weighted avg       0.96      0.96      0.96      1471
#
#
# 📚 Training Fold 2
# Epoch 1/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.6716 - loss: 4.7237 - val_accuracy: 0.8389 - val_loss: 2.3218 - learning_rate: 0.0010
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9385 - loss: 1.6017 - val_accuracy: 0.9245 - val_loss: 1.0567 - learning_rate: 0.0010
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9420 - loss: 0.8364 - val_accuracy: 0.8171 - val_loss: 1.1676 - learning_rate: 0.0010
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9390 - loss: 0.5471 - val_accuracy: 0.8654 - val_loss: 0.7708 - learning_rate: 0.0010
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9450 - loss: 0.4024 - val_accuracy: 0.8960 - val_loss: 0.5119 - learning_rate: 0.0010
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9319 - loss: 0.3606 - val_accuracy: 0.9327 - val_loss: 0.3805 - learning_rate: 0.0010
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.9431 - loss: 0.3461 - val_accuracy: 0.9504 - val_loss: 0.2940 - learning_rate: 0.0010
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.9530 - loss: 0.2728 - val_accuracy: 0.9361 - val_loss: 0.3094 - learning_rate: 0.0010
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9518 - loss: 0.2395 - val_accuracy: 0.8804 - val_loss: 0.4559 - learning_rate: 0.0010
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9359 - loss: 0.3375 - val_accuracy: 0.9497 - val_loss: 0.2995 - learning_rate: 0.0010
# Epoch 11/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9532 - loss: 0.2613 - val_accuracy: 0.9483 - val_loss: 0.2533 - learning_rate: 5.0000e-04
# Epoch 12/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.9500 - loss: 0.2352 - val_accuracy: 0.9531 - val_loss: 0.2441 - learning_rate: 5.0000e-04
# Epoch 13/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.9521 - loss: 0.2177 - val_accuracy: 0.9531 - val_loss: 0.2232 - learning_rate: 5.0000e-04
# Epoch 14/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.9544 - loss: 0.2199 - val_accuracy: 0.9565 - val_loss: 0.2004 - learning_rate: 5.0000e-04
# Epoch 15/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - accuracy: 0.9509 - loss: 0.1971 - val_accuracy: 0.9449 - val_loss: 0.2194 - learning_rate: 5.0000e-04
# Epoch 16/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.9510 - loss: 0.2081 - val_accuracy: 0.9517 - val_loss: 0.2227 - learning_rate: 5.0000e-04
# Epoch 17/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.9538 - loss: 0.2019 - val_accuracy: 0.9565 - val_loss: 0.2029 - learning_rate: 5.0000e-04
# Epoch 18/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9549 - loss: 0.1858 - val_accuracy: 0.9558 - val_loss: 0.1850 - learning_rate: 2.5000e-04
# Epoch 19/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9530 - loss: 0.1832 - val_accuracy: 0.9572 - val_loss: 0.1806 - learning_rate: 2.5000e-04
# Epoch 20/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9550 - loss: 0.1729 - val_accuracy: 0.9524 - val_loss: 0.1731 - learning_rate: 2.5000e-04
# Epoch 21/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.9520 - loss: 0.1709 - val_accuracy: 0.9381 - val_loss: 0.2394 - learning_rate: 2.5000e-04
# Epoch 22/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.9495 - loss: 0.1782 - val_accuracy: 0.9565 - val_loss: 0.1794 - learning_rate: 2.5000e-04
# Epoch 23/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.9537 - loss: 0.1612 - val_accuracy: 0.9565 - val_loss: 0.1711 - learning_rate: 2.5000e-04
# Epoch 24/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.9580 - loss: 0.1588 - val_accuracy: 0.9483 - val_loss: 0.2091 - learning_rate: 2.5000e-04
# Epoch 25/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9542 - loss: 0.1654 - val_accuracy: 0.9524 - val_loss: 0.1735 - learning_rate: 2.5000e-04
# Epoch 26/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9511 - loss: 0.1645 - val_accuracy: 0.9517 - val_loss: 0.1684 - learning_rate: 2.5000e-04
# Epoch 27/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9509 - loss: 0.1575 - val_accuracy: 0.9048 - val_loss: 0.3308 - learning_rate: 2.5000e-04
# Epoch 28/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.9494 - loss: 0.1829 - val_accuracy: 0.9558 - val_loss: 0.1851 - learning_rate: 2.5000e-04
# Epoch 29/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9505 - loss: 0.1656 - val_accuracy: 0.9558 - val_loss: 0.1763 - learning_rate: 2.5000e-04
# Epoch 30/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9549 - loss: 0.1575 - val_accuracy: 0.9517 - val_loss: 0.1630 - learning_rate: 1.2500e-04
# Epoch 31/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9535 - loss: 0.1513 - val_accuracy: 0.9490 - val_loss: 0.1694 - learning_rate: 1.2500e-04
# Epoch 32/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9553 - loss: 0.1476 - val_accuracy: 0.9558 - val_loss: 0.1586 - learning_rate: 1.2500e-04
# Epoch 33/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9584 - loss: 0.1358 - val_accuracy: 0.9477 - val_loss: 0.1526 - learning_rate: 1.2500e-04
# Epoch 34/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9513 - loss: 0.1460 - val_accuracy: 0.9477 - val_loss: 0.1516 - learning_rate: 1.2500e-04
# Epoch 35/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9584 - loss: 0.1492 - val_accuracy: 0.9490 - val_loss: 0.1821 - learning_rate: 1.2500e-04
# Epoch 36/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9547 - loss: 0.1423 - val_accuracy: 0.9545 - val_loss: 0.1467 - learning_rate: 1.2500e-04
# Epoch 37/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9549 - loss: 0.1429 - val_accuracy: 0.9483 - val_loss: 0.1600 - learning_rate: 1.2500e-04
# Epoch 38/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.9621 - loss: 0.1298 - val_accuracy: 0.9517 - val_loss: 0.1439 - learning_rate: 1.2500e-04
# Epoch 39/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9568 - loss: 0.1423 - val_accuracy: 0.9538 - val_loss: 0.1541 - learning_rate: 1.2500e-04
# Epoch 40/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9566 - loss: 0.1389 - val_accuracy: 0.9538 - val_loss: 0.1480 - learning_rate: 1.2500e-04
# Epoch 41/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9557 - loss: 0.1319 - val_accuracy: 0.9490 - val_loss: 0.1685 - learning_rate: 1.2500e-04
# Epoch 42/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9547 - loss: 0.1309 - val_accuracy: 0.9545 - val_loss: 0.1342 - learning_rate: 6.2500e-05
# Epoch 43/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9615 - loss: 0.1270 - val_accuracy: 0.9579 - val_loss: 0.1494 - learning_rate: 6.2500e-05
# Epoch 44/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9668 - loss: 0.1185 - val_accuracy: 0.9579 - val_loss: 0.1427 - learning_rate: 6.2500e-05
# Epoch 45/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9653 - loss: 0.1193 - val_accuracy: 0.9572 - val_loss: 0.1361 - learning_rate: 6.2500e-05
# Epoch 46/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9656 - loss: 0.1138 - val_accuracy: 0.9619 - val_loss: 0.1342 - learning_rate: 3.1250e-05
# Epoch 47/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9677 - loss: 0.1158 - val_accuracy: 0.9572 - val_loss: 0.1320 - learning_rate: 3.1250e-05
# Epoch 48/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9681 - loss: 0.1111 - val_accuracy: 0.9585 - val_loss: 0.1296 - learning_rate: 3.1250e-05
# Epoch 49/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.9670 - loss: 0.1115 - val_accuracy: 0.9619 - val_loss: 0.1322 - learning_rate: 3.1250e-05
# Epoch 50/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9706 - loss: 0.1075 - val_accuracy: 0.9585 - val_loss: 0.1264 - learning_rate: 3.1250e-05
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
#
# 🧾 Fold 2 Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       245
#            2       1.00      1.00      1.00       215
#            3       1.00      1.00      1.00       197
#            4       0.88      0.88      0.88       257
#            5       0.89      0.89      0.89       275
#            6       1.00      1.00      1.00       282
#
#     accuracy                           0.96      1471
#    macro avg       0.96      0.96      0.96      1471
# weighted avg       0.96      0.96      0.96      1471
#
#
# 📚 Training Fold 3
# Epoch 1/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - accuracy: 0.6678 - loss: 4.7532 - val_accuracy: 0.8245 - val_loss: 2.3922 - learning_rate: 0.0010
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9299 - loss: 1.6913 - val_accuracy: 0.8027 - val_loss: 1.6458 - learning_rate: 0.0010
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9352 - loss: 0.8958 - val_accuracy: 0.9075 - val_loss: 0.7285 - learning_rate: 0.0010
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9394 - loss: 0.5613 - val_accuracy: 0.9082 - val_loss: 0.5541 - learning_rate: 0.0010
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9402 - loss: 0.4255 - val_accuracy: 0.8782 - val_loss: 0.5965 - learning_rate: 0.0010
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.9450 - loss: 0.3461 - val_accuracy: 0.9211 - val_loss: 0.3918 - learning_rate: 0.0010
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9408 - loss: 0.3206 - val_accuracy: 0.9456 - val_loss: 0.3065 - learning_rate: 0.0010
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9386 - loss: 0.3180 - val_accuracy: 0.9517 - val_loss: 0.2882 - learning_rate: 0.0010
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9539 - loss: 0.2777 - val_accuracy: 0.9544 - val_loss: 0.2629 - learning_rate: 0.0010
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9460 - loss: 0.2511 - val_accuracy: 0.9367 - val_loss: 0.2571 - learning_rate: 0.0010
# Epoch 11/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9405 - loss: 0.2555 - val_accuracy: 0.9544 - val_loss: 0.2742 - learning_rate: 0.0010
# Epoch 12/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9374 - loss: 0.2857 - val_accuracy: 0.9524 - val_loss: 0.2786 - learning_rate: 0.0010
# Epoch 13/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9458 - loss: 0.2932 - val_accuracy: 0.9524 - val_loss: 0.2785 - learning_rate: 0.0010
# Epoch 14/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9554 - loss: 0.2489 - val_accuracy: 0.9463 - val_loss: 0.2522 - learning_rate: 5.0000e-04
# Epoch 15/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9491 - loss: 0.2288 - val_accuracy: 0.9517 - val_loss: 0.2143 - learning_rate: 5.0000e-04
# Epoch 16/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.9516 - loss: 0.2048 - val_accuracy: 0.9469 - val_loss: 0.2142 - learning_rate: 5.0000e-04
# Epoch 17/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9523 - loss: 0.1887 - val_accuracy: 0.9578 - val_loss: 0.1907 - learning_rate: 5.0000e-04
# Epoch 18/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9544 - loss: 0.1806 - val_accuracy: 0.9340 - val_loss: 0.2442 - learning_rate: 5.0000e-04
# Epoch 19/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9504 - loss: 0.1863 - val_accuracy: 0.9517 - val_loss: 0.2157 - learning_rate: 5.0000e-04
# Epoch 20/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9533 - loss: 0.1901 - val_accuracy: 0.9184 - val_loss: 0.3204 - learning_rate: 5.0000e-04
# Epoch 21/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9516 - loss: 0.1912 - val_accuracy: 0.9565 - val_loss: 0.1811 - learning_rate: 2.5000e-04
# Epoch 22/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9516 - loss: 0.1733 - val_accuracy: 0.9544 - val_loss: 0.1709 - learning_rate: 2.5000e-04
# Epoch 23/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 12s 133ms/step - accuracy: 0.9561 - loss: 0.1667 - val_accuracy: 0.9483 - val_loss: 0.1834 - learning_rate: 2.5000e-04
# Epoch 24/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 157ms/step - accuracy: 0.9562 - loss: 0.1643 - val_accuracy: 0.9374 - val_loss: 0.2259 - learning_rate: 2.5000e-04
# Epoch 25/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9526 - loss: 0.1668 - val_accuracy: 0.9537 - val_loss: 0.1747 - learning_rate: 2.5000e-04
# Epoch 26/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 161ms/step - accuracy: 0.9498 - loss: 0.1689 - val_accuracy: 0.9551 - val_loss: 0.1664 - learning_rate: 1.2500e-04
# Epoch 27/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 15s 158ms/step - accuracy: 0.9469 - loss: 0.1595 - val_accuracy: 0.9531 - val_loss: 0.1640 - learning_rate: 1.2500e-04
# Epoch 28/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 15s 162ms/step - accuracy: 0.9506 - loss: 0.1552 - val_accuracy: 0.9544 - val_loss: 0.1541 - learning_rate: 1.2500e-04
# Epoch 29/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 157ms/step - accuracy: 0.9577 - loss: 0.1462 - val_accuracy: 0.9558 - val_loss: 0.1481 - learning_rate: 1.2500e-04
# Epoch 30/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 150ms/step - accuracy: 0.9602 - loss: 0.1386 - val_accuracy: 0.9612 - val_loss: 0.1500 - learning_rate: 1.2500e-04
# Epoch 31/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 146ms/step - accuracy: 0.9553 - loss: 0.1491 - val_accuracy: 0.9585 - val_loss: 0.1437 - learning_rate: 1.2500e-04
# Epoch 32/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - accuracy: 0.9552 - loss: 0.1351 - val_accuracy: 0.9592 - val_loss: 0.1397 - learning_rate: 1.2500e-04
# Epoch 33/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 148ms/step - accuracy: 0.9567 - loss: 0.1362 - val_accuracy: 0.9571 - val_loss: 0.1444 - learning_rate: 1.2500e-04
# Epoch 34/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - accuracy: 0.9554 - loss: 0.1398 - val_accuracy: 0.9537 - val_loss: 0.1372 - learning_rate: 1.2500e-04
# Epoch 35/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 156ms/step - accuracy: 0.9561 - loss: 0.1316 - val_accuracy: 0.9551 - val_loss: 0.1363 - learning_rate: 1.2500e-04
# Epoch 36/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 152ms/step - accuracy: 0.9631 - loss: 0.1227 - val_accuracy: 0.9422 - val_loss: 0.1439 - learning_rate: 1.2500e-04
# Epoch 37/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 154ms/step - accuracy: 0.9519 - loss: 0.1337 - val_accuracy: 0.9605 - val_loss: 0.1353 - learning_rate: 1.2500e-04
# Epoch 38/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 158ms/step - accuracy: 0.9578 - loss: 0.1327 - val_accuracy: 0.9565 - val_loss: 0.1377 - learning_rate: 1.2500e-04
# Epoch 39/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 160ms/step - accuracy: 0.9609 - loss: 0.1219 - val_accuracy: 0.9524 - val_loss: 0.1493 - learning_rate: 1.2500e-04
# Epoch 40/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 153ms/step - accuracy: 0.9594 - loss: 0.1229 - val_accuracy: 0.9558 - val_loss: 0.1369 - learning_rate: 1.2500e-04
# Epoch 41/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 15s 166ms/step - accuracy: 0.9678 - loss: 0.1114 - val_accuracy: 0.9639 - val_loss: 0.1510 - learning_rate: 6.2500e-05
# Epoch 42/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 15s 160ms/step - accuracy: 0.9662 - loss: 0.1165 - val_accuracy: 0.9565 - val_loss: 0.1370 - learning_rate: 6.2500e-05
# Epoch 43/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - accuracy: 0.9659 - loss: 0.1092 - val_accuracy: 0.9633 - val_loss: 0.1235 - learning_rate: 6.2500e-05
# Epoch 44/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9645 - loss: 0.1115 - val_accuracy: 0.9626 - val_loss: 0.1254 - learning_rate: 6.2500e-05
# Epoch 45/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - accuracy: 0.9638 - loss: 0.1108 - val_accuracy: 0.9646 - val_loss: 0.1300 - learning_rate: 6.2500e-05
# Epoch 46/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.9714 - loss: 0.0974 - val_accuracy: 0.9646 - val_loss: 0.1225 - learning_rate: 6.2500e-05
# Epoch 47/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.9726 - loss: 0.1001 - val_accuracy: 0.9599 - val_loss: 0.1249 - learning_rate: 6.2500e-05
# Epoch 48/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9645 - loss: 0.1031 - val_accuracy: 0.9633 - val_loss: 0.1394 - learning_rate: 6.2500e-05
# Epoch 49/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9714 - loss: 0.0969 - val_accuracy: 0.9633 - val_loss: 0.1322 - learning_rate: 6.2500e-05
# Epoch 50/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.9753 - loss: 0.0927 - val_accuracy: 0.9633 - val_loss: 0.1271 - learning_rate: 3.1250e-05
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
#
# 🧾 Fold 3 Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       246
#            2       0.99      1.00      0.99       214
#            3       1.00      0.99      1.00       197
#            4       0.91      0.90      0.90       257
#            5       0.91      0.91      0.91       275
#            6       1.00      1.00      1.00       281
#
#     accuracy                           0.96      1470
#    macro avg       0.97      0.97      0.97      1470
# weighted avg       0.96      0.96      0.96      1470
#
#
# 📚 Training Fold 4
# Epoch 1/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 10s 83ms/step - accuracy: 0.6693 - loss: 4.7036 - val_accuracy: 0.8776 - val_loss: 2.2142 - learning_rate: 0.0010
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 8s 89ms/step - accuracy: 0.9251 - loss: 1.6736 - val_accuracy: 0.8517 - val_loss: 1.2914 - learning_rate: 0.0010
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 156ms/step - accuracy: 0.9336 - loss: 0.8355 - val_accuracy: 0.9279 - val_loss: 0.6455 - learning_rate: 0.0010
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 172ms/step - accuracy: 0.9353 - loss: 0.5628 - val_accuracy: 0.9395 - val_loss: 0.4205 - learning_rate: 0.0010
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 155ms/step - accuracy: 0.9392 - loss: 0.4205 - val_accuracy: 0.9327 - val_loss: 0.3944 - learning_rate: 0.0010
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 181ms/step - accuracy: 0.9492 - loss: 0.3365 - val_accuracy: 0.9299 - val_loss: 0.3272 - learning_rate: 0.0010
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 15s 161ms/step - accuracy: 0.9458 - loss: 0.3066 - val_accuracy: 0.9367 - val_loss: 0.3334 - learning_rate: 0.0010
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - accuracy: 0.9356 - loss: 0.3225 - val_accuracy: 0.9163 - val_loss: 0.3972 - learning_rate: 0.0010
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 174ms/step - accuracy: 0.9466 - loss: 0.3050 - val_accuracy: 0.9476 - val_loss: 0.2840 - learning_rate: 0.0010
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 156ms/step - accuracy: 0.9450 - loss: 0.2977 - val_accuracy: 0.9415 - val_loss: 0.2991 - learning_rate: 0.0010
# Epoch 11/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 159ms/step - accuracy: 0.9509 - loss: 0.2580 - val_accuracy: 0.9510 - val_loss: 0.2525 - learning_rate: 0.0010
# Epoch 12/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 161ms/step - accuracy: 0.9443 - loss: 0.2779 - val_accuracy: 0.9395 - val_loss: 0.3211 - learning_rate: 0.0010
# Epoch 13/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 15s 165ms/step - accuracy: 0.9437 - loss: 0.2789 - val_accuracy: 0.9497 - val_loss: 0.2567 - learning_rate: 0.0010
# Epoch 14/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 168ms/step - accuracy: 0.9481 - loss: 0.2381 - val_accuracy: 0.9313 - val_loss: 0.3386 - learning_rate: 0.0010
# Epoch 15/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 151ms/step - accuracy: 0.9470 - loss: 0.2762 - val_accuracy: 0.9483 - val_loss: 0.2322 - learning_rate: 5.0000e-04
# Epoch 16/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 121ms/step - accuracy: 0.9528 - loss: 0.2115 - val_accuracy: 0.9401 - val_loss: 0.2479 - learning_rate: 5.0000e-04
# Epoch 17/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 25s 165ms/step - accuracy: 0.9445 - loss: 0.2208 - val_accuracy: 0.9401 - val_loss: 0.2412 - learning_rate: 5.0000e-04
# Epoch 18/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 173ms/step - accuracy: 0.9531 - loss: 0.1873 - val_accuracy: 0.9497 - val_loss: 0.1918 - learning_rate: 5.0000e-04
# Epoch 19/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 172ms/step - accuracy: 0.9541 - loss: 0.1903 - val_accuracy: 0.9537 - val_loss: 0.1958 - learning_rate: 5.0000e-04
# Epoch 20/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 170ms/step - accuracy: 0.9569 - loss: 0.1843 - val_accuracy: 0.9510 - val_loss: 0.2111 - learning_rate: 5.0000e-04
# Epoch 21/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 15s 167ms/step - accuracy: 0.9555 - loss: 0.1809 - val_accuracy: 0.9476 - val_loss: 0.1878 - learning_rate: 5.0000e-04
# Epoch 22/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 169ms/step - accuracy: 0.9556 - loss: 0.1782 - val_accuracy: 0.9463 - val_loss: 0.1874 - learning_rate: 5.0000e-04
# Epoch 23/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 171ms/step - accuracy: 0.9515 - loss: 0.1776 - val_accuracy: 0.9456 - val_loss: 0.1990 - learning_rate: 5.0000e-04
# Epoch 24/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 176ms/step - accuracy: 0.9492 - loss: 0.1785 - val_accuracy: 0.9476 - val_loss: 0.1995 - learning_rate: 5.0000e-04
# Epoch 25/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 179ms/step - accuracy: 0.9442 - loss: 0.2070 - val_accuracy: 0.9354 - val_loss: 0.2366 - learning_rate: 5.0000e-04
# Epoch 26/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 136ms/step - accuracy: 0.9534 - loss: 0.1785 - val_accuracy: 0.9490 - val_loss: 0.1725 - learning_rate: 2.5000e-04
# Epoch 27/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.9547 - loss: 0.1622 - val_accuracy: 0.9537 - val_loss: 0.1643 - learning_rate: 2.5000e-04
# Epoch 28/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - accuracy: 0.9603 - loss: 0.1484 - val_accuracy: 0.9503 - val_loss: 0.1665 - learning_rate: 2.5000e-04
# Epoch 29/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - accuracy: 0.9554 - loss: 0.1519 - val_accuracy: 0.9497 - val_loss: 0.1594 - learning_rate: 2.5000e-04
# Epoch 30/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - accuracy: 0.9598 - loss: 0.1375 - val_accuracy: 0.9483 - val_loss: 0.1641 - learning_rate: 2.5000e-04
# Epoch 31/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.9521 - loss: 0.1535 - val_accuracy: 0.9435 - val_loss: 0.2153 - learning_rate: 2.5000e-04
# Epoch 32/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 12s 133ms/step - accuracy: 0.9529 - loss: 0.1538 - val_accuracy: 0.9503 - val_loss: 0.1699 - learning_rate: 2.5000e-04
# Epoch 33/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 12s 132ms/step - accuracy: 0.9587 - loss: 0.1426 - val_accuracy: 0.9503 - val_loss: 0.1440 - learning_rate: 1.2500e-04
# Epoch 34/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - accuracy: 0.9596 - loss: 0.1400 - val_accuracy: 0.9517 - val_loss: 0.1455 - learning_rate: 1.2500e-04
# Epoch 35/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9639 - loss: 0.1299 - val_accuracy: 0.9531 - val_loss: 0.1482 - learning_rate: 1.2500e-04
# Epoch 36/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9621 - loss: 0.1289 - val_accuracy: 0.9558 - val_loss: 0.1401 - learning_rate: 1.2500e-04
# Epoch 37/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.9578 - loss: 0.1263 - val_accuracy: 0.9551 - val_loss: 0.1471 - learning_rate: 1.2500e-04
# Epoch 38/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9651 - loss: 0.1189 - val_accuracy: 0.9537 - val_loss: 0.1351 - learning_rate: 1.2500e-04
# Epoch 39/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 15s 126ms/step - accuracy: 0.9627 - loss: 0.1236 - val_accuracy: 0.9551 - val_loss: 0.1377 - learning_rate: 1.2500e-04
# Epoch 40/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - accuracy: 0.9622 - loss: 0.1185 - val_accuracy: 0.9585 - val_loss: 0.1355 - learning_rate: 1.2500e-04
# Epoch 41/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 12s 127ms/step - accuracy: 0.9623 - loss: 0.1153 - val_accuracy: 0.9578 - val_loss: 0.1307 - learning_rate: 1.2500e-04
# Epoch 42/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 73ms/step - accuracy: 0.9651 - loss: 0.1166 - val_accuracy: 0.9578 - val_loss: 0.1356 - learning_rate: 1.2500e-04
# Epoch 43/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.9639 - loss: 0.1127 - val_accuracy: 0.9639 - val_loss: 0.1162 - learning_rate: 1.2500e-04
# Epoch 44/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9623 - loss: 0.1106 - val_accuracy: 0.9592 - val_loss: 0.1270 - learning_rate: 1.2500e-04
# Epoch 45/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9652 - loss: 0.1082 - val_accuracy: 0.9558 - val_loss: 0.1336 - learning_rate: 1.2500e-04
# Epoch 46/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 9s 96ms/step - accuracy: 0.9665 - loss: 0.1058 - val_accuracy: 0.9626 - val_loss: 0.1221 - learning_rate: 1.2500e-04
# Epoch 47/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 11s 117ms/step - accuracy: 0.9710 - loss: 0.1021 - val_accuracy: 0.9612 - val_loss: 0.1202 - learning_rate: 6.2500e-05
# Epoch 48/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 10s 108ms/step - accuracy: 0.9712 - loss: 0.0962 - val_accuracy: 0.9619 - val_loss: 0.1135 - learning_rate: 6.2500e-05
# Epoch 49/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 174ms/step - accuracy: 0.9679 - loss: 0.0979 - val_accuracy: 0.9605 - val_loss: 0.1295 - learning_rate: 6.2500e-05
# Epoch 50/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 31s 284ms/step - accuracy: 0.9715 - loss: 0.0964 - val_accuracy: 0.9653 - val_loss: 0.1132 - learning_rate: 6.2500e-05
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 107ms/step
#
# 🧾 Fold 4 Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       245
#            2       1.00      1.00      1.00       214
#            3       1.00      1.00      1.00       198
#            4       0.90      0.90      0.90       257
#            5       0.91      0.91      0.91       275
#            6       1.00      1.00      1.00       281
#
#     accuracy                           0.97      1470
#    macro avg       0.97      0.97      0.97      1470
# weighted avg       0.97      0.97      0.97      1470
#
#
# 📚 Training Fold 5
# Epoch 1/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 44s 200ms/step - accuracy: 0.6878 - loss: 4.7099 - val_accuracy: 0.8476 - val_loss: 2.3469 - learning_rate: 0.0010
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 10s 110ms/step - accuracy: 0.9356 - loss: 1.6633 - val_accuracy: 0.6252 - val_loss: 2.2286 - learning_rate: 0.0010
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 10s 112ms/step - accuracy: 0.9398 - loss: 0.8144 - val_accuracy: 0.9367 - val_loss: 0.6020 - learning_rate: 0.0010
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 10s 111ms/step - accuracy: 0.9332 - loss: 0.5825 - val_accuracy: 0.9374 - val_loss: 0.4873 - learning_rate: 0.0010
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - accuracy: 0.9278 - loss: 0.4625 - val_accuracy: 0.9313 - val_loss: 0.4421 - learning_rate: 0.0010
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.9498 - loss: 0.3656 - val_accuracy: 0.9422 - val_loss: 0.3810 - learning_rate: 0.0010
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - accuracy: 0.9407 - loss: 0.3383 - val_accuracy: 0.9347 - val_loss: 0.3386 - learning_rate: 0.0010
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 10s 104ms/step - accuracy: 0.9356 - loss: 0.3154 - val_accuracy: 0.9463 - val_loss: 0.2835 - learning_rate: 0.0010
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.9442 - loss: 0.3003 - val_accuracy: 0.9388 - val_loss: 0.2849 - learning_rate: 0.0010
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 27s 278ms/step - accuracy: 0.9445 - loss: 0.2765 - val_accuracy: 0.9510 - val_loss: 0.2628 - learning_rate: 0.0010
# Epoch 11/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 33s 194ms/step - accuracy: 0.9498 - loss: 0.2377 - val_accuracy: 0.9211 - val_loss: 0.3115 - learning_rate: 0.0010
# Epoch 12/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 252ms/step - accuracy: 0.9489 - loss: 0.2315 - val_accuracy: 0.9497 - val_loss: 0.2545 - learning_rate: 0.0010
# Epoch 13/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 27s 98ms/step - accuracy: 0.9469 - loss: 0.2206 - val_accuracy: 0.5531 - val_loss: 1.7673 - learning_rate: 0.0010
# Epoch 14/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.9331 - loss: 0.3419 - val_accuracy: 0.9361 - val_loss: 0.3933 - learning_rate: 0.0010
# Epoch 15/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - accuracy: 0.9461 - loss: 0.3099 - val_accuracy: 0.9537 - val_loss: 0.2471 - learning_rate: 0.0010
# Epoch 16/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 10s 108ms/step - accuracy: 0.9480 - loss: 0.2415 - val_accuracy: 0.8912 - val_loss: 0.5333 - learning_rate: 0.0010
# Epoch 17/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - accuracy: 0.9409 - loss: 0.2501 - val_accuracy: 0.9156 - val_loss: 0.3541 - learning_rate: 0.0010
# Epoch 18/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 169ms/step - accuracy: 0.9403 - loss: 0.2438 - val_accuracy: 0.9442 - val_loss: 0.2397 - learning_rate: 0.0010
# Epoch 19/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.9419 - loss: 0.2297 - val_accuracy: 0.9524 - val_loss: 0.2423 - learning_rate: 0.0010
# Epoch 20/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 26s 282ms/step - accuracy: 0.9463 - loss: 0.2218 - val_accuracy: 0.9544 - val_loss: 0.2380 - learning_rate: 0.0010
# Epoch 21/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 24s 262ms/step - accuracy: 0.9464 - loss: 0.2387 - val_accuracy: 0.9367 - val_loss: 0.3117 - learning_rate: 0.0010
# Epoch 22/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 42s 268ms/step - accuracy: 0.9477 - loss: 0.2452 - val_accuracy: 0.9524 - val_loss: 0.2093 - learning_rate: 0.0010
# Epoch 23/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 26s 278ms/step - accuracy: 0.9427 - loss: 0.2313 - val_accuracy: 0.8898 - val_loss: 0.4122 - learning_rate: 0.0010
# Epoch 24/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 26s 284ms/step - accuracy: 0.9461 - loss: 0.2302 - val_accuracy: 0.9327 - val_loss: 0.2537 - learning_rate: 0.0010
# Epoch 25/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 34s 206ms/step - accuracy: 0.9408 - loss: 0.2431 - val_accuracy: 0.9395 - val_loss: 0.2604 - learning_rate: 0.0010
# Epoch 26/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 171ms/step - accuracy: 0.9508 - loss: 0.2414 - val_accuracy: 0.9408 - val_loss: 0.2210 - learning_rate: 5.0000e-04
# Epoch 27/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 10s 111ms/step - accuracy: 0.9486 - loss: 0.2012 - val_accuracy: 0.9551 - val_loss: 0.1995 - learning_rate: 5.0000e-04
# Epoch 28/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - accuracy: 0.9507 - loss: 0.1738 - val_accuracy: 0.9544 - val_loss: 0.1669 - learning_rate: 5.0000e-04
# Epoch 29/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.9521 - loss: 0.1632 - val_accuracy: 0.9537 - val_loss: 0.1674 - learning_rate: 5.0000e-04
# Epoch 30/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.9484 - loss: 0.1765 - val_accuracy: 0.9571 - val_loss: 0.1703 - learning_rate: 5.0000e-04
# Epoch 31/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 24s 257ms/step - accuracy: 0.9557 - loss: 0.1599 - val_accuracy: 0.9565 - val_loss: 0.1760 - learning_rate: 5.0000e-04
# Epoch 32/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 26s 278ms/step - accuracy: 0.9460 - loss: 0.1616 - val_accuracy: 0.9544 - val_loss: 0.1597 - learning_rate: 2.5000e-04
# Epoch 33/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 25s 272ms/step - accuracy: 0.9514 - loss: 0.1485 - val_accuracy: 0.9517 - val_loss: 0.1707 - learning_rate: 2.5000e-04
# Epoch 34/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 27s 287ms/step - accuracy: 0.9577 - loss: 0.1533 - val_accuracy: 0.9571 - val_loss: 0.1451 - learning_rate: 2.5000e-04
# Epoch 35/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 25s 271ms/step - accuracy: 0.9506 - loss: 0.1481 - val_accuracy: 0.9558 - val_loss: 0.1541 - learning_rate: 2.5000e-04
# Epoch 36/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 249ms/step - accuracy: 0.9512 - loss: 0.1473 - val_accuracy: 0.9571 - val_loss: 0.1485 - learning_rate: 2.5000e-04
# Epoch 37/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 26s 282ms/step - accuracy: 0.9564 - loss: 0.1370 - val_accuracy: 0.9599 - val_loss: 0.1338 - learning_rate: 2.5000e-04
# Epoch 38/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 24s 255ms/step - accuracy: 0.9521 - loss: 0.1392 - val_accuracy: 0.9531 - val_loss: 0.1480 - learning_rate: 2.5000e-04
# Epoch 39/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 25s 270ms/step - accuracy: 0.9509 - loss: 0.1449 - val_accuracy: 0.9592 - val_loss: 0.1356 - learning_rate: 2.5000e-04
# Epoch 40/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 40s 264ms/step - accuracy: 0.9513 - loss: 0.1374 - val_accuracy: 0.9374 - val_loss: 0.2078 - learning_rate: 2.5000e-04
# Epoch 41/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 32s 167ms/step - accuracy: 0.9567 - loss: 0.1408 - val_accuracy: 0.9565 - val_loss: 0.1384 - learning_rate: 1.2500e-04
# Epoch 42/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 256ms/step - accuracy: 0.9583 - loss: 0.1341 - val_accuracy: 0.9571 - val_loss: 0.1334 - learning_rate: 1.2500e-04
# Epoch 43/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 43s 279ms/step - accuracy: 0.9544 - loss: 0.1294 - val_accuracy: 0.9578 - val_loss: 0.1324 - learning_rate: 1.2500e-04
# Epoch 44/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 27s 290ms/step - accuracy: 0.9525 - loss: 0.1301 - val_accuracy: 0.9612 - val_loss: 0.1282 - learning_rate: 1.2500e-04
# Epoch 45/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 22s 238ms/step - accuracy: 0.9561 - loss: 0.1314 - val_accuracy: 0.9578 - val_loss: 0.1273 - learning_rate: 1.2500e-04
# Epoch 46/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 25s 272ms/step - accuracy: 0.9581 - loss: 0.1273 - val_accuracy: 0.9592 - val_loss: 0.1236 - learning_rate: 1.2500e-04
# Epoch 47/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 26s 285ms/step - accuracy: 0.9565 - loss: 0.1256 - val_accuracy: 0.9605 - val_loss: 0.1275 - learning_rate: 1.2500e-04
# Epoch 48/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 24s 252ms/step - accuracy: 0.9515 - loss: 0.1276 - val_accuracy: 0.9612 - val_loss: 0.1220 - learning_rate: 1.2500e-04
# Epoch 49/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 27s 288ms/step - accuracy: 0.9548 - loss: 0.1166 - val_accuracy: 0.9578 - val_loss: 0.1264 - learning_rate: 1.2500e-04
# Epoch 50/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 26s 278ms/step - accuracy: 0.9506 - loss: 0.1211 - val_accuracy: 0.9612 - val_loss: 0.1263 - learning_rate: 1.2500e-04
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step
#
# 🧾 Fold 5 Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       245
#            2       1.00      1.00      1.00       215
#            3       1.00      1.00      1.00       197
#            4       0.88      0.90      0.89       258
#            5       0.91      0.88      0.89       274
#            6       1.00      1.00      1.00       281
#
#     accuracy                           0.96      1470
#    macro avg       0.96      0.96      0.96      1470
# weighted avg       0.96      0.96      0.96      1470
#
#
# ✅ Average Macro F1-Score across 5 folds: 0.9648 ± 0.0024
